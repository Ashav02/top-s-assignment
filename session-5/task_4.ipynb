# %%
#Create a tuple called insta_filters with 4 Instagram filter names.
#Try to update the second filter and observe what error you get.
#Explain in a comment why this happens

insta_filter = ('Focus','Face Frame','Dazzling','Body Frame')
type(insta_filter)
# Out:
# tuple

# %%
insta_filter
# Out:
# ('Focus', 'Face Frame', 'Dazzling', 'Body Frame')

# %%
insta_filter[1] = "Browse Effects"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 insta_filter[1] = "Browse Effects"
#
# TypeError: 'tuple' object does not support item assignment

# %%
#this gives an error because tuples are immutable .
#TypeError: 'tuple' object does not support item assignment

#Tuples are immutable.
