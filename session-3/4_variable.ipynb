# %%
rating = 4.5
print(rating)
type(rating)
# Out:
# 4.5
# float

# %%
price = 150000
print(price)
type(price)
# Out:
# 150000
# int

# %%
product_name = "Samsung S26 Ultra"
print(product_name)
type(product_name)
# Out:
# Samsung S26 Ultra
# str

# %%
product_name_1 = "Samsung S25 Ultra"
is_premium_user = True

type(product_name_1)
type(is_premium_user)
# Out:
# bool
