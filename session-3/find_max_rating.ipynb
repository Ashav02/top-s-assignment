# %%
spotify_ratings = ['4.5', '3.0', '5', '4.2']

float_rating = [float(rating) for rating in spotify_ratings]
print(float_rating)
# Out:
# [4.5, 3.0, 5.0, 4.2]

# %%
highest_rating = max(float_rating)
print(highest_rating)
# Out:
# 5.0
