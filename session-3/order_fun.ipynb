# %%
def is_discount_applicable(amount):
    if amount > 500:
        return True
    else:
        return False

# %%
print(is_discount_applicable(450))
# Out:
# False

# %%
print(is_discount_applicable(750))
# Out:
# True
