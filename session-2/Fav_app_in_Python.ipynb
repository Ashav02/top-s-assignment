# %%
user_name = "Ashav Patel"
fav_app = "Groww"
daily_use_hours = 2

# %%
print(user_name) 
type(user_name)
# Out:
# Ashav Patel
# str

# %%
print(fav_app)
type(fav_app)
# Out:
# Groww
# str

# %%
print(daily_use_hours)
type(daily_use_hours)
# Out:
# 2
# int
