# %%
product_name = "Samsung A36 5G"
price = 24500
is_avalible = "True"

# %%
print(product_name)
type(product_name)
# Out:
# Samsung A36 5G
# str

# %%
print(price)
type(price)
# Out:
# 24500
# int

# %%
print(is_avalible)
type(is_avalible)
# Out:
# True
# str
