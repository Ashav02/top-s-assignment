# %%
#use string slicing to extract and print only the brand name and the model

prodcut_name = "Apple iPhone 14 Pro Max"

# %%
index = prodcut_name.find(" ")

# %%
brand_name = prodcut_name[:index]
modale = prodcut_name[index+1:]

# %%
print(brand_name)
print(modale)
# Out:
# Apple
# iPhone 14 Pro Max
