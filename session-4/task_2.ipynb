# %%
def  clean_brand_name(name):
    name = name.strip()
    name = name.replace("-", " ")
    return name

# %%
brand = clean_brand_name(" OnePlus-Nord ")
print(brand)
# Out:
# OnePlus Nord

# %%
brand_1 = clean_brand_name("Samsung Galaxy-A36 ")
print(brand_1)
# Out:
# Samsung Galaxy A36
